# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import xarray as xr
import rioxarray as rioxr
import matplotlib.pyplot as plt

# %%
fires = gpd.read_file("fire_perimeters/California_Fire_Perimeters_(all).shp")
thomas_fire = gpd.read_file("data/thomas_fire.shp")

# %% [markdown]
# 3a: Construct a file path to the Landsat data using os and import it using rioxr.open_rasterio()

# %%
fp = os.path.join("/courses/EDS220/data/hwk4_landsat_data", "landsat8-2018-01-26-sb-simplified.nc")
landsat = rioxr.open_rasterio(fp)
landsat.head()
# Out:
# <xarray.Dataset> Size: 1kB
# Dimensions:      (band: 1, x: 5, y: 5)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 40B 1.213e+05 1.216e+05 ... 1.221e+05 1.224e+05
#   * y            (y) float64 40B 3.952e+06 3.952e+06 ... 3.952e+06 3.951e+06
#     spatial_ref  int64 8B 0
# Data variables:
#     red          (band, y, x) float64 200B ...
#     green        (band, y, x) float64 200B ...
#     blue         (band, y, x) float64 200B ...
#     nir08        (band, y, x) float64 200B ...
#     swir22       (band, y, x) float64 200B ...

# %% [markdown]
# 3b: Explore the data and write a brief summary of the information you obtained from the preliminary information. Your summary should include the a description of the data’s variables and dimensions.
#
# The landsat data is an xarray.Dataset with one band, captured from the Landsat satellite. It has five color variables (red, green, blue, near infrared, and shortwave infrared). The dataset has 731 rows and 870 columns, and has a bounding box with the coordinates 121170, 3755160, 356070, 3952530.

# %%
#3b
print('Height: ', landsat.rio.height)
print('Width: ', landsat.rio.width)
print('Bounding Box: ')
print(landsat.rio.bounds(), '\n')
# Out:
# Height:  731
# Width:  870
# Bounding Box:
# (121170.0, 3755160.0, 356070.0, 3952530.0)

# %% [markdown]
# 3c: Drop the band dimension of the data. HINT: squeeze() and drop_vars()

# %%
landsat = landsat.squeeze().drop_vars("band")

# %% [markdown]
# 3d: Without creating any new variables:
#
# select the red, green, and blue variables (in that order) of the xarray.Dataset holding the Landsat data,
# convert it to a numpy.array using the to_array() method, and then
# use .plot.imshow() to create an RGB image with the data. There will be a warning, that’s ok

# %% [markdown]
# 3e: Adjust the scale used for plotting the bands to get a true color image. HINT: Check the robust parameter. The issue here is the clouds: their RGB values are outliers and cause the other values to be squished when plotting.

# %%
landsat[['red', 'green', 'blue']].to_array().plot.imshow(robust = True)

# %% [markdown]
# 3f: In a markdown cell write a brief explanation comparing the ouputs for parts (a) and (b) (presuming you mean parts 3(d) and (e))

# %% [markdown]
# 3(d) is a true color image from the landsat data of the Santa Barbara county area.
# 3(e) is a false color, where we have replaced the red, green, and blue bands with shortwave infrared, near infrared, and red bands respectively.

# %% [markdown]
# 4: Without creating any new variables, create a false color image by plotting the short-wave infrared (swir22), near-infrared, and red variables (in that order).

# %%
landsat[['swir22', 'nir08', 'red']].to_array().plot.imshow(robust = True)

# %% [markdown]
# 5: Create a map showing the shortwave infrared/near-infrared/red false color image together with the Thomas Fire perimeter

# %%
thomas_fire = thomas_fire.to_crs(landsat.rio.crs) # matching CRS between the two objects
assert thomas_fire.crs == landsat.rio.crs # checking the change was successful
landsat_aspect_ratio = landsat.rio.width / landsat.rio.height # establishing an aspect ratio for the landsat data

# %%
fig, ax = plt.subplots(figsize= (10, 6*landsat_aspect_ratio))

ax.axis('off')

landsat[['swir22', 'nir08', 'red']].to_array().plot.imshow(robust = True, ax=ax)

thomas_fire.boundary.plot(ax = ax, color = "maroon")

ax.set_title("Thomas Fire Scar\nDecember 2017", fontsize=16, weight='bold', pad=20)
fig.suptitle("  Landsat Composite with Fire Boundary", fontsize=12, weight='bold', y=0.91, color = "maroon")

fig.text(
    0.5, 0.06,
    "Landsat Imagery: https://planetarycomputer.microsoft.com/dataset/landsat-c2-l2\nThomas Fire Boundary: https://catalog.data.gov/dataset/california-fire-perimeters-all-b3436",  # Text
    ha="center", va="bottom", fontsize=10, color="gray"
)


plt.show()
